# %%
# This workbook covers the basics of working with pinecone
# See https://www.youtube.com/watch?v=Q6616MuRmKU
# !pip install pinecone-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pinecone-client
#   Obtaining dependency information for pinecone-client from https://files.pythonhosted.org/packages/df/d4/cffbb61236c6c1d7510e835c1ff843e4e7d705ed59d21c0e5b6dc1cb4fd8/pinecone_client-2.2.4-py3-none-any.whl.metadata
#   Using cached pinecone_client-2.2.4-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: requests>=2.19.0 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (2.31.0)
# Requirement already satisfied: pyyaml>=5.4 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (6.0.1)
# Collecting loguru>=0.5.0 (from pinecone-client)
#   Obtaining dependency information for loguru>=0.5.0 from https://files.pythonhosted.org/packages/03/0a/4f6fed21aa246c6b49b561ca55facacc2a44b87d65b8b92362a8e99ba202/loguru-0.7.2-py3-none-any.whl.metadata
#   Downloading loguru-0.7.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (4.8.0)
# Collecting dnspython>=2.0.0 (from pinecone-client)
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/f6/b4/0a9bee52c50f226a3cbfb54263d02bb421c7f2adc136520729c2c689c1e5/dnspython-2.4.2-py3-none-any.whl.metadata
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (1.26.17)
# Requirement already satisfied: tqdm>=4.64.1 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (4.66.1)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from pinecone-client) (1.24.3)
# Requirement already satisfied: colorama>=0.3.4 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from loguru>=0.5.0->pinecone-client) (0.4.6)
# Collecting win32-setctime>=1.0.0 (from loguru>=0.5.0->pinecone-client)
#   Using cached win32_setctime-1.1.0-py3-none-any.whl (3.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pinecone-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pinecone-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\donnp\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pinecone-client) (2023.5.7)
# Downloading pinecone_client-2.2.4-py3-none-any.whl (179 kB)
#    ---------------------------------------- 0.0/179.4 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/179.4 kB 640.0 kB/s eta 0:00:01
#    ------ -------------------------------- 30.7/179.4 kB 640.0 kB/s eta 0:00:01
#    ------------- ------------------------- 61.4/179.4 kB 409.6 kB/s eta 0:00:01
#    ------------------------------------ - 174.1/179.4 kB 871.5 kB/s eta 0:00:01
#    -------------------------------------- 179.4/179.4 kB 899.6 kB/s eta 0:00:00
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    ---------------------------------------- 300.4/300.4 kB 9.4 MB/s eta 0:00:00
# Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.5 kB ? eta -:--:--
#    ---------------------------------------- 62.5/62.5 kB ? eta 0:00:00
# Installing collected packages: win32-setctime, dnspython, loguru, pinecone-client
# Successfully installed dnspython-2.4.2 loguru-0.7.2 pinecone-client-2.2.4 win32-setctime-1.1.0

# %%
# Get environment variables
from dotenv import find_dotenv, load_dotenv
load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# Creating embeddings

# %%
# Create embedder object
import os
from langchain.embeddings.openai import OpenAIEmbeddings

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY') or 'OPENAI_API_KEY'

model_name = 'text-embedding-ada-002'
embedder = OpenAIEmbeddings(
    model=model_name,
    openai_api_key=OPENAI_API_KEY
)

# %%
# Will have to get texts from jsonl or json file created during chunking
texts = [
    'this is the first chunk of text',
    'then another second chunk of text is here'
]

result = embedder.embed_documents(texts)
len(result), len(result[0])
# Out:
# (2, 1536)

# %%
# The result is just a bunch of vectors. No text is included.
print(result)
# Out:
# [[0.003042488170397273, -0.009244673312589876, -0.009786147017888436, -0.03269973194642018, 0.0003900096684716083, 0.026360526910249826, -0.013933043994962485, -0.006748611620636086, -0.020932581841329418, -0.03647684079889781, -0.000640936505382856, 0.03925024102316199, -0.015200884070874039, 0.009700304227537364, 0.013285916406733161, 0.0022599923886739374, 0.010453084767374936, 0.008689993454001543, 0.010770044553522196, -0.009495600469643239, -0.012420878907319938, 0.011998265238241915, -0.008452272450237953, -0.00800984955122527, -0.002682606057751961, -0.02892262123129751, 0.008313603184082757, -0.021064648962162244, -0.0060948809557618755, -0.007263672088032584, -0.018383693673571504, -0.01032101764654211, 0.002345835877516897, -0.02188346213109371, -0.002027224856547158, -0.0023970118169904285, -0.014949957845143193, -0.017696945762827827, 0.019308161656756254, -0.02624166594270677, 0.019942081229050772, -0.00027507029632045866, -0.00324719146263014, -0.00672880145937891, -0.009984247699137675, -0.011093608347636858, 0.007118398348248727, -0.0039818130760330165, -0.023283370259160607, 0.004430839983013102, 0.03182808857639452, 0.013107625886741097, -0.022557003888547617, -0.006652863283995168, -0.007481581999216482, 0.026756726410103272, -0.010089900650745923, 0.010116313888647985, 0.012037885560756266, 0.005213335299075179, -0.002443235216149666, 0.012764252862691776, -0.017089438497112856, -0.006834454876648416, -0.0047907216299971555, -0.001575721562994611, -0.00868338944603414, -0.0007985911884988468, 0.0003175792902439757, 0.013985870470766609, 0.025541711878673323, 0.01792145968197913, -0.009832370417047674, -0.004744498696499177, 0.02113068159125614, 0.006959918455175098, -0.008828662720156739, 0.0005839826992220773, 0.00940975674796965, 0.0009723415694286354, 0.027918914465729094, -0.014197177305305621, 0.009812560255790498, 0.03998981540970979, 0.0039025728966655725, -0.015848011659103364, 0.01579518518329924, 0.02209476989695524, -0.013708530075811184, -0.013200072685059572, 0.0003068488832424344, 0.012922733221426664, 0.009363533348810413, 0.018925166447547548, -0.009931420292011035, 0.015266917631290452, 0.003344590801262909, 0.018872339971743424, 0.01704982003724354, -0.027998153248112764, -0.004836945029156393, -0.0019100155894878426, -0.020285454253100094, -0.0037044726810775918, -0.03983133411965239, 0.0023920592766761345, 0.029001861876326213, -0.008828662720156739, 0.01704982003724354, 0.017789392561146304, -0.007105191729297696, 0.02224004317107784, -0.016072525578254664, -0.03214505115650933, -0.0014131143977719836, -0.006867471656856623, 0.012282208709842226, -0.030269702883560286, -0.02130236903460332, -0.031141342528295878, 0.004998726926213724, 0.03946155065166856, 0.026637865442560218, -0.013140643132610562, 0.0023722493482495883, 0.0007333832454936737, -0.021289162881313543, -0.024141803750606428, 0.006646259741689023, -0.0059066858208024825, 0.023745604250752984, 0.009436169985871712, 0.031379064463381984, -0.0021510374330819884, -0.020866549212235522, 0.014038696946570733, -0.00601564124205569, -0.009568237106704538, -0.03148471741499023, -0.02284755043679281, 0.019651534680805573, 0.03998981540970979, -0.0197836018016384, -0.00597932292352504, -0.00028105456736051603, 0.024894584290444, 0.005629345891508316, 0.002014018237596127, 0.005576518950042934, -0.022794723960988687, 0.018053526802811956, -0.0012595868121820187, -0.0030391863992442008, -0.0003241826288233198, 0.0015748961784140003, 0.04339713706891352, 0.004285566708890503, -0.0013718435389270401, 0.01092192090428968, -0.012480309391091465, -0.006108088040374164, 0.0021857049824514168, 0.010426670598150358, 0.002662796129325415, 0.014619790974383644, 0.046196953325047314, 0.020958996010553996, -0.012011472322854204, 0.012698219302275363, -0.006748611620636086, 0.0033544958818914968, 0.02955654080359203, -0.04006905605473849, 0.006256662852819206, -0.014025489861958442, 0.009640873743765837, 0.02102502863964789, 0.023256957952581064,  ...

# %% [markdown]
# Vector databse

# %%
# Give the index a name
index_name = 'langchain-retrieval-augmentation'

# %%
import pinecone # !install pinecone-client
import tqdm

# find API key in console at app.pinecone.io
PINECONE_API_KEY = os.getenv('PINECONE_API_KEY') or 'PINECONE_API_KEY'
# find ENV (cloud region) next to API key in console
PINECONE_ENVIRONMENT = os.getenv('PINECONE_ENVIRONMENT') or 'PINECONE_ENVIRONMENT'

# Initialise the pinecone client object
pinecone.init(
    api_key=PINECONE_API_KEY,
    environment=PINECONE_ENVIRONMENT
)
# Out:
# C:\Users\donnp\AppData\Roaming\Python\Python311\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Create the index if it does not exist
if index_name not in pinecone.list_indexes():
    pinecone.create_index(
        name=index_name,
        metric='cosine',
        dimension=len(result[0])  # 1536 dim of text-embedding-ada-002
    )

# %%
# Retrieve the index
# index = pinecone.GRPCIndex(index_name)
index = pinecone.Index(index_name)

index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %% [markdown]
# Get some data

# %%
# !pip install -Uq apache_beam
# !pip install -Uq datasets==2.12.0
from datasets import load_dataset

data = load_dataset("wikipedia", "20220301.simple", split='train[:10]') # Just 10 docs for now
data
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\donnp\\AppData\\Roaming\\Python\\Python311\\site-packages\\~yarrow\\arrow.dll'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Downloading and preparing dataset wikipedia/20220301.simple to C:/Users/donnp/.cache/huggingface/datasets/wikipedia/20220301.simple/2.0.0/aa542ed919df55cc5d3347f42dd4521d05ca68751f50dbc32bae2a7f1e167559...
# Downloading:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/235M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\donnp\source\repos\AiGf\aiutils\encodingTut.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().system('pip install -Uq datasets==2.12.0')
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> from datasets import load_dataset
# ----> <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> data = load_dataset("wikipedia", "20220301.simple", split='train[:10]') # Just 10 docs for now
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a> data
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\load.py:1797, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    1794 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    1796 # Download and prepare data
# -> 1797 builder_instance.download_and_prepare(
#    1798     download_config=download_config,
#    1799     download_mode=download_mode,
#    1800     verification_mode=verification_mode,
#    1801     try_from_hf_gcs=try_from_hf_gcs,
#    1802     num_proc=num_proc,
#    1803     storage_options=storage_options,
#    1804 )
#    1806 # Build dataset for splits
#    1807 keep_in_memory = (
#    1808     keep_in_memory if keep_in_memory is not None else is_small_dataset(builder_instance.info.dataset_size)
#    1809 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\builder.py:901, in DatasetBuilder.download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     899         self.info.size_in_bytes = self.info.dataset_size + self.info.download_size
#     900         # Save info
# --> 901         self._save_info()
#     903 # Download post processing resources
#     904 self.download_post_processing_resources(dl_manager)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\datasets\builder.py:2037, in BeamBasedBuilder._save_info(self)
#    2036 def _save_info(self):
# -> 2037     import apache_beam as beam
#    2039     fs = beam.io.filesystems.FileSystems
#    2040     path_join = os.path.join if not is_remote_filesystem(self._fs) else posixpath.join
#
# ModuleNotFoundError: No module named 'apache_beam'

# %% [markdown]
# Indexing

# %%
from tqdm.auto import tqdm
from uuid import uuid4

batch_limit = 100

texts = []
metadatas = []

for i, record in enumerate(tqdm(data)):
    # first get metadata fields for this record
    metadata = {
        'wiki-id': str(record['id']),
        'source': record['url'],
        'title': record['title']
    }
    # now we create chunks from the record text
    record_texts = text_splitter.split_text(record['text'])
    # create individual metadata dicts for each chunk
    record_metadatas = [{
        "chunk": j, "text": text, **metadata
    } for j, text in enumerate(record_texts)]
    # append these to current batches
    texts.extend(record_texts)
    metadatas.extend(record_metadatas)
    # if we have reached the batch_limit we can add texts
    if len(texts) >= batch_limit:
        ids = [str(uuid4()) for _ in range(len(texts))]
        embeddings = embedder.embed_documents(texts)
        index.upsert(vectors=zip(ids, embeddings, metadatas))
        texts = []
        metadatas = []

if len(texts) > 0:
    ids = [str(uuid4()) for _ in range(len(texts))]
    embeddings = embedder.embed_documents(texts)
    index.upsert(vectors=zip(ids, embeddings, metadatas))
    
index.describe_index_stats()

# %% [markdown]
# Creating a Vector Store and Querying

# %%
from langchain.vectorstores import Pinecone

index_name = 'langchain-retrieval-augmentation'
text_field = "text"

# switch back to normal index for langchain
index = pinecone.Index(index_name)

# Create vector store
vectorstore = Pinecone(
    index, embedder.embed_query, text_field
)
# Out:
# C:\Users\donnp\AppData\Roaming\Python\Python311\site-packages\langchain\vectorstores\pinecone.py:59: UserWarning: Passing in `embedding` as a Callable is deprecated. Please pass in an Embeddings object instead.
#   warnings.warn(

# %%
# Query the vector store
query = "What are some of the common topics I write about?"
query = "Summarise what I have written about sex and polyamory?"
# query = "What are some of the common topics I write about?"
# query = "What are some of the common topics I write about?"
# query = "What are some of the common topics I write about?"
# query = "What are some of the common topics I write about?"

vectorstore.similarity_search(
    query,  # our search query
    k=6  # return k most relevant docs
)
# Out:
# [Document(page_content="the polyamorous community is incredibly diverse. Not all poly relationships are hypersexual; in fact, many focus on emotional connections, deep love, and support rather than constant carnal activities. Polyamory isn't just about sexit's about personal growth and exploring the many facets of love and connection. People choose this lifestyle for various reasons, and for some, it's about much more than what happens in the bedroom. Believe it or not, some individuals intentionally choose polyamory as a path to a more balanced, less sex-focused life. They seek meaningful connections without the constant pressure to perform sexually, debunking the notion that polyamory is all about more action. The idea that becoming polyamorous guarantees more sex is, indeed, a myth. While polyamorous individuals might have more opportunities for intimacy and connection, that doesn't necessarily translate into a higher frequency of sexual activity. It's all about choice, communication, and the unique dynamics of each individual relationship. So, if you're considering a foray into polyamory, don't do it solely in the pursuit of more sex. Instead, embrace it as a path to explore love, connection, and personal growth in all its forms. Monogamy Versus Non-monogamy: Who Is More Sexually Satisfied | Psychology Today", metadata={'author': 'Donn Pienaar', 'chunk_num': 1.0, 'comments': '', 'date_created': datetime.datetime(2023, 9, 24, 14, 33), 'date_last_updated': datetime.datetime(2023, 10, 7, 13, 55), 'file_name': 'Article True or False If You Want Less Sex, Become Polyamorous.docx', 'file_type': 'docx', 'keywords': '', 'title': ''}),
#  Document(page_content='Requirements and high level design of Peterfenpoly.co.uk What pages should exist on the website? Homepage Welcome & objectives Welcome to the Peterborough & Fenland Polyamory website, or Peterfenpoly for short or even shorter: PFP. If you are new (or maybe not so new ) to polyamory, you are in the right place. Our objective is to raise awareness of polyamory in the communities in which we live and work. We believe that polyamory in its many forms is a valid relationship alternative, and we seek to normalise it. On this website you will find lots of useful resources to help educate and inform you about polyamory. We hope you find it useful. If you have any questions, please <contact> us. What is polyamory? According to the Cambridge dictionary polyamory is the practice of having sexual or romantic relationships with two or more people at the same time. This definition reminds me of a bikini: what it reveals is interesting, but what it conceals is critical. There is so much more to polyamory than just sex and romance. It may be easier to answer the question by considering what polyamory is not. Polyamory is not cheating. It is not a one-night stand. It is not a fad. It is a long-term commitment to people that stems from the belief that that love is endless and there is no logical or ethical reason why a person cannot love more than one person at a time. We all intuitively know that we can love more than one parent, sibling, child, friend or pet at a time. So why is it that the societal norm says we can only (romantically, sexually) love one person at a time? If this question makes you feel uneasy, you are not alone. There are many people just like you People who feel they have more to give, people who feel they want more. Why consider polyamory? There are many reasons to consider poly, probably as many as there are poly people. For me personally poly means a radical new level of honesty that I felt unable to achieve in monogamous relationships. Im not saying this is true for everyone, Im just saying its true for me. Is this you? Provide descriptions of personas so that reader can resonate (See Poly group content plan) Map of Peterborough and the fens and a description, listing the major towns, population and so on. Articles and blogs FAQ &', metadata={'author': 'Donn Pienaar', 'chunk_num': 0.0, 'comments': '', 'date_created': datetime.datetime(2023, 8, 29, 19, 8), 'date_last_updated': datetime.datetime(2023, 8, 29, 20, 17), 'file_name': 'Peterfenpoly website requirements.docx', 'file_type': 'docx', 'keywords': '', 'title': ''}),
#  Document(page_content='Title: "True or False: If You Want More Sex, Become Polyamorous?" Extract: How does polyamory affect sex life? Are polyamorous people really having more sex than their monogamous counterparts, or is that just a spicy rumour floating around in the dating world? Today, we\'re diving into the world of polyamory to debunk the myth that more partners necessarily mean more action in the bedroom. So, true or false: if you want less sex, should you consider becoming polyamorous? Let\'s find out! First and foremost, let\'s clear the air about one thing: polyamory isn\'t a never-ending orgy. Contrary to popular belief, it\'s not a perpetual sexual carousel with partners hopping on and off. Sure, polyamorous people might have more opportunities for intimacy, but that doesn\'t necessarily translate into constant romps. It\'s time to address the elephant in the room: does having multiple partners actually lead to more sex? While there isn\'t direct evidence that polyamory is positively correlated with more sex, there is also no evidence that polygamous people have less sex than their monogamous counterparts (1). Interestingly, non-monogamous people report higher levels of sexual satisfaction. I am not sure what the reasons for this are, but Im curious to hear your speculations. In the world of polyamory, scheduling is an art form. Balancing multiple partners\' needs and desires takes skill, and sometimes, that means prioritizing emotional connection over sexual gratification. It\'s a complex dance that often leads to fewer romps than one might think. Effective communication is a cornerstone of successful polyamorous relationships. Ironically, all that talking and emotional connection can sometimes overshadow the physical side of things. It\'s a trade-off where conversation can take precedence over making love. It is rumoured that some polyamorous folks experience a phenomenon known as Poly FOMOThe Fear of Missing Out on sexual opportunities. With multiple partners exploring their desires, it\'s natural to wonder if you\'re missing out on something amazing. I tried to find research to support/refute this claim but could not find either. I think it is safe to say that people are polyamorous for many reasons, and the perception of access to sexual opportunities may be one of them. And building on that, it\'s essential to remember that the polyamorous community is incredibly diverse. Not all poly relationships are hypersexual; in fact,', metadata={'author': 'Donn Pienaar', 'chunk_num': 0.0, 'comments': '', 'date_created': datetime.datetime(2023, 9, 24, 14, 33), 'date_last_updated': datetime.datetime(2023, 10, 7, 13, 55), 'file_name': 'Article True or False If You Want Less Sex, Become Polyamorous.docx', 'file_type': 'docx', 'keywords': '', 'title': ''}),
#  Document(page_content="not the case for everyone. Relationships can shift and change as we grow. Some people may move between monogamy and polyamory as their needs and desires evolve. Sometimes, our desire for connection can become all-consuming, making us focus solely on our poly nature. But it's essential to remember the depth and complexity of everyone's identities. Polyamory, like any other relationship style, is just one part of who we are. By respecting this diversity and approaching people with an open and non-judgmental attitude, we can build a more inclusive and understanding society for everyone.", metadata={'author': 'Donn Pienaar', 'chunk_num': 1.0, 'comments': '', 'date_created': datetime.datetime(2023, 9, 17, 9, 27), 'date_last_updated': datetime.datetime(2023, 9, 17, 10, 7), 'file_name': 'Article Should we be defined by poly 20230917 1107.docx', 'file_type': 'docx', 'keywords': '', 'title': ''}),
#  Document(page_content='Article: Myths About Polyamory: Debunking Misconceptions in Non-Monogamous Relationships Polyamory, a term coined from the Greek "poly" meaning many, and the Latin "amor" meaning love, is a relationship style that has gained increased visibility and popularity in recent years. However, like any unconventional lifestyle, polyamory is surrounded by myths and misconceptions that can lead to misunderstandings and misjudgements. In this article, we\'ll explore some common myths about polyamory and shed light on the realities of non-monogamous relationships. Myth 1: Polyamory is Just a Form of Cheating One of the most persistent myths about polyamory is that it\'s essentially a way to cheat while still maintaining a veneer of respectability. This misconception arises from a failure to distinguish between consensual non-monogamy and infidelity. In reality, polyamory is built on open and honest communication among all involved parties. Partners in polyamorous relationships are fully aware of and consent to the arrangement, making it fundamentally different from cheating. Myth 2: Polyamory is All About Sex While sex can be an element in polyamorous relationships, reducing polyamory to just sexual experiences is a gross oversimplification. Polyamory is about forming multiple emotional connections and meaningful relationships, just like in monogamous relationships. Love, trust, and emotional intimacy are equally important components of polyamorous connections. Myth 3: Polyamory is Only for Promiscuous People Another common misconception is that polyamorous individuals are inherently promiscuous or driven by an insatiable desire for multiple sexual partners. In reality, polyamory is about consensual and ethical non-monogamy, not promiscuity. It emphasizes establishing meaningful connections and fostering emotional intimacy while respecting the boundaries and agreements set by all parties involved. Myth 4: Polyamory is Unstable There is a prevailing belief that polyamorous relationships are inherently unstable and prone to rapid changes and breakups. Just like monogamous relationships, the stability of a polyamorous relationship depends on the individuals involved and their ability to communicate, establish trust, and maintain commitment. Polyamorous relationships can be just as stable and long-lasting as monogamous ones. Myth 5: It\'s Just a Phase Some people believe that those who practice polyamory are simply going through a temporary phase that they will eventually outgrow. Polyamory', metadata={'author': 'Donn Pienaar', 'chunk_num': 0.0, 'comments': '', 'date_created': datetime.datetime(2023, 10, 15, 11, 9), 'date_last_updated': datetime.datetime(2023, 10, 16, 8, 2), 'file_name': 'Article Debunking Misconceptions in Non-Monogamous Relationships.docx', 'file_type': 'docx', 'keywords': '', 'title': ''}),
#  Document(page_content="the most impactful idea is to initiate local polyamory events. They don't have to revolve around poly-specific topics; it could be a simple evening walk or a friendly poker game. By taking the lead in organizing these events, we not only enrich our lives but also pave the way for a flourishing community. You might be amazed by the number of local residents secretly intrigued by polyamory, just waiting for a community like yours to emerge. So, small-town polyamorists, what are your thoughts and experiences? Share your success stories and the lessons learned along the way. Together, we can make love's boundaries a little less binding in our cozy corners of the world.", metadata={'author': 'Donn Pienaar', 'chunk_num': 1.0, 'comments': '', 'date_created': datetime.datetime(2023, 9, 10, 12, 40), 'date_last_updated': datetime.datetime(2023, 10, 5, 7, 5), 'file_name': 'Article city vs village poly 20230910 1341.docx', 'file_type': 'docx', 'keywords': '', 'title': ''})]

# %% [markdown]
# Generative Question-Answering

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQA

# completion llm
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name='gpt-3.5-turbo',
    temperature=0.0
)

qa = RetrievalQA.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever()
)

qa.run(query)
# Out:
# "Polyamory is not solely about sex; it focuses on emotional connections, deep love, and support. While polyamorous individuals may have more opportunities for intimacy, it doesn't necessarily mean they have more sex. The frequency of sexual activity in polyamorous relationships varies based on individual dynamics and choices. Polyamory is about choice, communication, and exploring love and personal growth in all its forms. It's important to debunk the myth that polyamory guarantees more sex and to approach the topic with understanding and respect for the diverse experiences within the polyamorous community."

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import RetrievalQAWithSourcesChain

# completion llm
llm = ChatOpenAI(
    openai_api_key=OPENAI_API_KEY,
    model_name='gpt-3.5-turbo',
    temperature=0.0
)

qa_with_sources = RetrievalQAWithSourcesChain.from_chain_type(
    llm=llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever()
)

qa_with_sources(query)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\donnp\source\repos\AiGf\aiutils\encodingTut.ipynb Cell 21 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> llm = ChatOpenAI(
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a>     openai_api_key=OPENAI_API_KEY,
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>     model_name='gpt-3.5-turbo',
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>     temperature=0.0
#       <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a> )
#      <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a> qa_with_sources = RetrievalQAWithSourcesChain.from_chain_type(
#      <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a>     llm=llm,
#      <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a>     chain_type="stuff",
#      <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>     retriever=vectorstore.as_retriever()
#      <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a> )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/donnp/source/repos/AiGf/aiutils/encodingTut.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a> qa_with_sources(query)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:308, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     306 except BaseException as e:
#     307     run_manager.on_chain_error(e)
# --> 308     raise e
#     309 run_manager.on_chain_end(outputs)
#     310 final_outputs: Dict[str, Any] = self.prep_outputs(
#     311     inputs, outputs, return_only_outputs
#     312 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:302, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     295 run_manager = callback_manager.on_chain_start(
#     296     dumpd(self),
#     297     inputs,
#     298     name=run_name,
#     299 )
#     300 try:
#     301     outputs = (
# --> 302         self._call(inputs, run_manager=run_manager)
#     303         if new_arg_supported
#     304         else self._call(inputs)
#     305     )
#     306 except BaseException as e:
#     307     run_manager.on_chain_error(e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\qa_with_sources\base.py:155, in BaseQAWithSourcesChain._call(self, inputs, run_manager)
#     152 else:
#     153     docs = self._get_docs(inputs)  # type: ignore[call-arg]
# --> 155 answer = self.combine_documents_chain.run(
#     156     input_documents=docs, callbacks=_run_manager.get_child(), **inputs
#     157 )
#     158 answer, sources = self._split_sources(answer)
#     159 result: Dict[str, Any] = {
#     160     self.answer_key: answer,
#     161     self.sources_answer_key: sources,
#     162 }
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:508, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     503     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     504         _output_key
#     505     ]
#     507 if kwargs and not args:
# --> 508     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     509         _output_key
#     510     ]
#     512 if not kwargs and not args:
#     513     raise ValueError(
#     514         "`run` supported with either positional arguments or keyword arguments,"
#     515         " but none were provided."
#     516     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:308, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     306 except BaseException as e:
#     307     run_manager.on_chain_error(e)
# --> 308     raise e
#     309 run_manager.on_chain_end(outputs)
#     310 final_outputs: Dict[str, Any] = self.prep_outputs(
#     311     inputs, outputs, return_only_outputs
#     312 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\base.py:302, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     295 run_manager = callback_manager.on_chain_start(
#     296     dumpd(self),
#     297     inputs,
#     298     name=run_name,
#     299 )
#     300 try:
#     301     outputs = (
# --> 302         self._call(inputs, run_manager=run_manager)
#     303         if new_arg_supported
#     304         else self._call(inputs)
#     305     )
#     306 except BaseException as e:
#     307     run_manager.on_chain_error(e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\combine_documents\base.py:119, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     117 # Other keys are assumed to be needed for LLM prediction
#     118 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 119 output, extra_return_dict = self.combine_docs(
#     120     docs, callbacks=_run_manager.get_child(), **other_keys
#     121 )
#     122 extra_return_dict[self.output_key] = output
#     123 return extra_return_dict
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\combine_documents\stuff.py:169, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     155 def combine_docs(
#     156     self, docs: List[Document], callbacks: Callbacks = None, **kwargs: Any
#     157 ) -> Tuple[str, dict]:
#     158     """Stuff all documents into one prompt and pass to LLM.
#     159
#     160     Args:
#    (...)
#     167         element returned is a dictionary of other keys to return.
#     168     """
# --> 169     inputs = self._get_inputs(docs, **kwargs)
#     170     # Call predict on the LLM.
#     171     return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\combine_documents\stuff.py:125, in StuffDocumentsChain._get_inputs(self, docs, **kwargs)
#     110 """Construct inputs from kwargs and docs.
#     111
#     112 Format and the join all the documents together into one input with name
#    (...)
#     122     dictionary of inputs to LLMChain
#     123 """
#     124 # Format each document according to the prompt
# --> 125 doc_strings = [format_document(doc, self.document_prompt) for doc in docs]
#     126 # Join the documents together to put them in the prompt.
#     127 inputs = {
#     128     k: v
#     129     for k, v in kwargs.items()
#     130     if k in self.llm_chain.prompt.input_variables
#     131 }
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\chains\combine_documents\stuff.py:125, in <listcomp>(.0)
#     110 """Construct inputs from kwargs and docs.
#     111
#     112 Format and the join all the documents together into one input with name
#    (...)
#     122     dictionary of inputs to LLMChain
#     123 """
#     124 # Format each document according to the prompt
# --> 125 doc_strings = [format_document(doc, self.document_prompt) for doc in docs]
#     126 # Join the documents together to put them in the prompt.
#     127 inputs = {
#     128     k: v
#     129     for k, v in kwargs.items()
#     130     if k in self.llm_chain.prompt.input_variables
#     131 }
#
# File ~\AppData\Roaming\Python\Python311\site-packages\langchain\schema\prompt_template.py:212, in format_document(doc, prompt)
#     208 if len(missing_metadata) > 0:
#     209     required_metadata = [
#     210         iv for iv in prompt.input_variables if iv != "page_content"
#     211     ]
# --> 212     raise ValueError(
#     213         f"Document prompt requires documents to have metadata variables: "
#     214         f"{required_metadata}. Received document with missing metadata: "
#     215         f"{list(missing_metadata)}."
#     216     )
#     217 document_info = {k: base_info[k] for k in prompt.input_variables}
#     218 return prompt.format(**document_info)
#
# ValueError: Document prompt requires documents to have metadata variables: ['source']. Received document with missing metadata: ['source'].
